# %% [markdown]
# ## Data Cleaning the Samples

# %% [markdown]
# #### Import dependencies

# %%
import pandas as pd

# %% [markdown]
# #### Read in the (already cleaned) csv files containing annual data

# %%
sample_2014 = pd.read_csv("2014_Crime_Data.csv")
sample_2015 = pd.read_csv("2015_Crime_Data.csv")
sample_2016 = pd.read_csv("2016_Crime_Data.csv")

# %% [markdown]
# #### Get row and column length for each of the csv files

# %%
# Getting row and column info for each file
print("There are " + str(sample_2014.shape) + " rows and columns for 2014 data")
print("There are " + str(sample_2015.shape) + " rows and columns for 2015 data")
print("There are " + str(sample_2016.shape) + " rows and columns for 2016 data")
# Out:
# There are (10160, 6) rows and columns for 2014 data
# There are (9643, 6) rows and columns for 2015 data
# There are (9365, 6) rows and columns for 2016 data

# %%
sample_2015.shape
# Out:
# (9643, 6)

# %%
sample_2016.shape
# Out:
# (9365, 6)

# %% [markdown]
# #### Begin merging the files

# %%
sample_14_15 = pd.concat([sample_2014, sample_2015])

# %%
sample_14_15_16 = pd.concat([sample_14_15, sample_2016])

# %% [markdown]
# #### Check rows and columns again

# %%
sample_14_15_16.shape
# Out:
# (29168, 6)

# %% [markdown]
# #### Preview the DataFrame

# %%
sample_14_15_16.head()
# Out:
#           GO Highest Offense Desc Highest NIBRS/UCR Offense Description  \
# 0  THEFT                                       Theft: All Other Larceny
# 1  THEFT BY SHOPLIFTING                              Theft: Shoplifting
# 2  BURGLARY OF VEHICLE                                       Theft: BOV
# 3  AUTO THEFT                                                Auto Theft
# 4  THEFT                                       Theft: All Other Larceny
#
#            GO Report Date                                        GO Location  \
# 0  02/24/2014 12:00:00 AM  3101 GUADALUPE ST                             ...
# 1  08/18/2014 12:00:00 AM  1000 E 41ST ST                                ...
# 2  08/22/2014 12:00:00 AM  117 W WILLIAM CANNON DR                       ...
# 3  07/19/2014 12:00:00 AM  6407 SPRINGDALE RD                            ...
# 4  07/14/2014 12:00:00 AM  7201 BLESSING AVE                             ...
#
#            Clearance Date  GO Location Zip
# 0  02/25/2014 12:00:00 AM          78705.0
# 1  08/21/2014 12:00:00 AM          78751.0
# 2  08/27/2014 12:00:00 AM          78745.0
# 3  07/20/2014 12:00:00 AM          78723.0
# 4  07/15/2014 12:00:00 AM          78752.0

# %% [markdown]
# #### Re-create the DataFrame with only the columns we want to keep

# %%
sample_14_15_16 = sample_14_15_16[['GO Highest Offense Desc', 
                                   'Highest NIBRS/UCR Offense Description',
                                   'GO Report Date', 
                                   'GO Location', 
                                   'GO Location Zip']]

# %% [markdown]
# #### Save the data to a csv and preview it

# %%
sample_14_15_16.to_csv("Crime_Samples_Zipcode.csv")

# %%
sample_14_15_16.head(3)
# Out:
#           GO Highest Offense Desc Highest NIBRS/UCR Offense Description  \
# 0  THEFT                                       Theft: All Other Larceny
# 1  THEFT BY SHOPLIFTING                              Theft: Shoplifting
# 2  BURGLARY OF VEHICLE                                       Theft: BOV
#
#            GO Report Date                                        GO Location  \
# 0  02/24/2014 12:00:00 AM  3101 GUADALUPE ST                             ...
# 1  08/18/2014 12:00:00 AM  1000 E 41ST ST                                ...
# 2  08/22/2014 12:00:00 AM  117 W WILLIAM CANNON DR                       ...
#
#    GO Location Zip
# 0          78705.0
# 1          78751.0
# 2          78745.0

# %% [markdown]
# #### Check for duplicates

# %%
# Check for duplicates
sample_14_15_16.duplicated().sum()
# Out:
# 3605

# %%
# how large will our DataFrame be after removing duplicates?
sample_14_15_16.shape[0] - sample_14_15_16.duplicated().sum()
# Out:
# 25563

# %% [markdown]
# #### Drop the duplicated rows

# %%
sample_14_15_16 = sample_14_15_16.drop_duplicates()

# %% [markdown]
# #### Double check the row length

# %%
sample_14_15_16.shape[0]
# Out:
# 25563

# %% [markdown]
# #### Check for rows that have null values and calculate how many in each area

# %%
sample_14_15_16.isnull().sum()
# Out:
# GO Highest Offense Desc                    0
# Highest NIBRS/UCR Offense Description      0
# GO Report Date                             0
# GO Location                              445
# GO Location Zip                          101
# dtype: int64

# %% [markdown]
# #### Remove the null values from the DataFrame

# %%
sample_14_15_16 = sample_14_15_16.dropna()

# %% [markdown]
# #### Double check the null values

# %%
sample_14_15_16.isnull().sum()
# Out:
# GO Highest Offense Desc                  0
# Highest NIBRS/UCR Offense Description    0
# GO Report Date                           0
# GO Location                              0
# GO Location Zip                          0
# dtype: int64

# %% [markdown]
# #### Checking to see what type of data we are working with

# %%
sample_14_15_16.dtypes
# Out:
# GO Highest Offense Desc                   object
# Highest NIBRS/UCR Offense Description     object
# GO Report Date                            object
# GO Location                               object
# GO Location Zip                          float64
# dtype: object

# %% [markdown]
# #### Preview the DataFrame

# %%
sample_14_15_16.head()
# Out:
#           GO Highest Offense Desc Highest NIBRS/UCR Offense Description  \
# 0  THEFT                                       Theft: All Other Larceny
# 1  THEFT BY SHOPLIFTING                              Theft: Shoplifting
# 2  BURGLARY OF VEHICLE                                       Theft: BOV
# 3  AUTO THEFT                                                Auto Theft
# 4  THEFT                                       Theft: All Other Larceny
#
#            GO Report Date                                        GO Location  \
# 0  02/24/2014 12:00:00 AM  3101 GUADALUPE ST                             ...
# 1  08/18/2014 12:00:00 AM  1000 E 41ST ST                                ...
# 2  08/22/2014 12:00:00 AM  117 W WILLIAM CANNON DR                       ...
# 3  07/19/2014 12:00:00 AM  6407 SPRINGDALE RD                            ...
# 4  07/14/2014 12:00:00 AM  7201 BLESSING AVE                             ...
#
#    GO Location Zip
# 0          78705.0
# 1          78751.0
# 2          78745.0
# 3          78723.0
# 4          78752.0

# %% [markdown]
# #### The Zip Code column looks odd with that .0 at the end...
# ##### We duplicated the zip code column, only we renamed it and turned the values into integers

# %%
sample_14_15_16['Zip'] = sample_14_15_16['GO Location Zip'].astype(int)

# %%
sample_14_15_16.head()
# Out:
#           GO Highest Offense Desc Highest NIBRS/UCR Offense Description  \
# 0  THEFT                                       Theft: All Other Larceny
# 1  THEFT BY SHOPLIFTING                              Theft: Shoplifting
# 2  BURGLARY OF VEHICLE                                       Theft: BOV
# 3  AUTO THEFT                                                Auto Theft
# 4  THEFT                                       Theft: All Other Larceny
#
#            GO Report Date                                        GO Location  \
# 0  02/24/2014 12:00:00 AM  3101 GUADALUPE ST                             ...
# 1  08/18/2014 12:00:00 AM  1000 E 41ST ST                                ...
# 2  08/22/2014 12:00:00 AM  117 W WILLIAM CANNON DR                       ...
# 3  07/19/2014 12:00:00 AM  6407 SPRINGDALE RD                            ...
# 4  07/14/2014 12:00:00 AM  7201 BLESSING AVE                             ...
#
#    GO Location Zip    Zip
# 0          78705.0  78705
# 1          78751.0  78751
# 2          78745.0  78745
# 3          78723.0  78723
# 4          78752.0  78752

# %% [markdown]
# #### Changed the 'Zip' column values back into a string

# %%
sample_14_15_16['Zip'] = sample_14_15_16['Zip'].astype(str)

# %%
sample_14_15_16.head()
# Out:
#           GO Highest Offense Desc Highest NIBRS/UCR Offense Description  \
# 0  THEFT                                       Theft: All Other Larceny
# 1  THEFT BY SHOPLIFTING                              Theft: Shoplifting
# 2  BURGLARY OF VEHICLE                                       Theft: BOV
# 3  AUTO THEFT                                                Auto Theft
# 4  THEFT                                       Theft: All Other Larceny
#
#            GO Report Date                                        GO Location  \
# 0  02/24/2014 12:00:00 AM  3101 GUADALUPE ST                             ...
# 1  08/18/2014 12:00:00 AM  1000 E 41ST ST                                ...
# 2  08/22/2014 12:00:00 AM  117 W WILLIAM CANNON DR                       ...
# 3  07/19/2014 12:00:00 AM  6407 SPRINGDALE RD                            ...
# 4  07/14/2014 12:00:00 AM  7201 BLESSING AVE                             ...
#
#    GO Location Zip    Zip
# 0          78705.0  78705
# 1          78751.0  78751
# 2          78745.0  78745
# 3          78723.0  78723
# 4          78752.0  78752

# %% [markdown]
# ####  Dropped the unnecessary zip column

# %%
del sample_14_15_16['GO Location Zip']

# %%
sample_14_15_16.head()
# Out:
#           GO Highest Offense Desc Highest NIBRS/UCR Offense Description  \
# 0  THEFT                                       Theft: All Other Larceny
# 1  THEFT BY SHOPLIFTING                              Theft: Shoplifting
# 2  BURGLARY OF VEHICLE                                       Theft: BOV
# 3  AUTO THEFT                                                Auto Theft
# 4  THEFT                                       Theft: All Other Larceny
#
#            GO Report Date                                        GO Location  \
# 0  02/24/2014 12:00:00 AM  3101 GUADALUPE ST                             ...
# 1  08/18/2014 12:00:00 AM  1000 E 41ST ST                                ...
# 2  08/22/2014 12:00:00 AM  117 W WILLIAM CANNON DR                       ...
# 3  07/19/2014 12:00:00 AM  6407 SPRINGDALE RD                            ...
# 4  07/14/2014 12:00:00 AM  7201 BLESSING AVE                             ...
#
#      Zip
# 0  78705
# 1  78751
# 2  78745
# 3  78723
# 4  78752

# %% [markdown]
# #### Saved the new DataFrame to a .csv

# %%
sample_14_15_16.to_csv('Crime_Zipcode.csv')

# %%
sample_14_15_16['City'] = 'Austin'
sample_14_15_16['State'] = 'TX'

# %%
sample_14_15_16.head()
# Out:
#           GO Highest Offense Desc Highest NIBRS/UCR Offense Description  \
# 0  THEFT                                       Theft: All Other Larceny
# 1  THEFT BY SHOPLIFTING                              Theft: Shoplifting
# 2  BURGLARY OF VEHICLE                                       Theft: BOV
# 3  AUTO THEFT                                                Auto Theft
# 4  THEFT                                       Theft: All Other Larceny
#
#            GO Report Date                                        GO Location  \
# 0  02/24/2014 12:00:00 AM  3101 GUADALUPE ST                             ...
# 1  08/18/2014 12:00:00 AM  1000 E 41ST ST                                ...
# 2  08/22/2014 12:00:00 AM  117 W WILLIAM CANNON DR                       ...
# 3  07/19/2014 12:00:00 AM  6407 SPRINGDALE RD                            ...
# 4  07/14/2014 12:00:00 AM  7201 BLESSING AVE                             ...
#
#      Zip    City State
# 0  78705  Austin    TX
# 1  78751  Austin    TX
# 2  78745  Austin    TX
# 3  78723  Austin    TX
# 4  78752  Austin    TX

# %%
sample_14_15_16['Full_Address'] = sample_14_15_16['GO Location'] + sample_14_15_16['City'] + " " + sample_14_15_16['State'] + " " +  sample_14_15_16['Zip']

# %%
sample_14_15_16.head()
# Out:
#           GO Highest Offense Desc Highest NIBRS/UCR Offense Description  \
# 0  THEFT                                       Theft: All Other Larceny
# 1  THEFT BY SHOPLIFTING                              Theft: Shoplifting
# 2  BURGLARY OF VEHICLE                                       Theft: BOV
# 3  AUTO THEFT                                                Auto Theft
# 4  THEFT                                       Theft: All Other Larceny
#
#            GO Report Date                                        GO Location  \
# 0  02/24/2014 12:00:00 AM  3101 GUADALUPE ST                             ...
# 1  08/18/2014 12:00:00 AM  1000 E 41ST ST                                ...
# 2  08/22/2014 12:00:00 AM  117 W WILLIAM CANNON DR                       ...
# 3  07/19/2014 12:00:00 AM  6407 SPRINGDALE RD                            ...
# 4  07/14/2014 12:00:00 AM  7201 BLESSING AVE                             ...
#
#      Zip    City State                                       Full_Address
# 0  78705  Austin    TX  3101 GUADALUPE ST                             ...
# 1  78751  Austin    TX  1000 E 41ST ST                                ...
# 2  78745  Austin    TX  117 W WILLIAM CANNON DR                       ...
# 3  78723  Austin    TX  6407 SPRINGDALE RD                            ...
# 4  78752  Austin    TX  7201 BLESSING AVE                             ...

# %%
sample_14_15_16.columns
# Out:
# Index(['GO Highest Offense Desc', 'Highest NIBRS/UCR Offense Description',
#        'GO Report Date', 'GO Location', 'Zip', 'City', 'State',
#        'Full_Address'],
#       dtype='object')

# %%
sample_14_15_16 = sample_14_15_16[['Highest NIBRS/UCR Offense Description',
       'GO Report Date',
       'Full_Address']]
sample_14_15_16.head()
# Out:
#   Highest NIBRS/UCR Offense Description          GO Report Date  \
# 0              Theft: All Other Larceny  02/24/2014 12:00:00 AM
# 1                    Theft: Shoplifting  08/18/2014 12:00:00 AM
# 2                            Theft: BOV  08/22/2014 12:00:00 AM
# 3                            Auto Theft  07/19/2014 12:00:00 AM
# 4              Theft: All Other Larceny  07/14/2014 12:00:00 AM
#
#                                         Full_Address
# 0  3101 GUADALUPE ST                             ...
# 1  1000 E 41ST ST                                ...
# 2  117 W WILLIAM CANNON DR                       ...
# 3  6407 SPRINGDALE RD                            ...
# 4  7201 BLESSING AVE                             ...

# %%
sample_14_15_16.rename_axis({'Highest NIBRS/UCR Offense Description': 'Offense_Description',
                            'GO Report Date': 'Report_Date'}, axis=1, inplace=True)

# %%
sample_14_15_16.head()
# Out:
#         Offense_Description             Report_Date  \
# 0  Theft: All Other Larceny  02/24/2014 12:00:00 AM
# 1        Theft: Shoplifting  08/18/2014 12:00:00 AM
# 2                Theft: BOV  08/22/2014 12:00:00 AM
# 3                Auto Theft  07/19/2014 12:00:00 AM
# 4  Theft: All Other Larceny  07/14/2014 12:00:00 AM
#
#                                         Full_Address
# 0  3101 GUADALUPE ST                             ...
# 1  1000 E 41ST ST                                ...
# 2  117 W WILLIAM CANNON DR                       ...
# 3  6407 SPRINGDALE RD                            ...
# 4  7201 BLESSING AVE                             ...

# %%
m = {'Agg Assault': 'Agg Assault',
     'Theft': 'Theft',
     'Robbery': 'Robbery',
     'Burglary': 'Burglary',
     'Auto Theft': 'Theft: Auto Theft',
     'Murder' : 'Murder',
     'Burglary / \nBreaking & Entering': 'Burglary: Breaking & Entering',
     'Homicide: Murder & Nonnegligent Manslaughter': 'Homicide: Murder & Non-negligent Manslaughter',
     'Aggravated Assault': 'Aggravated Assault',
     'Theft: Pocket Picking': 'Theft: Pocket Picking',
     'Theft: Purse Snatching': 'Theft: Purse Snatching',
     'Theft: Shoplifting': 'Theft: Shoplifting',
     'Theft: from Building': 'Theft: from Building',
     'Theft: Coin Op Machine': 'Theft: Coin Op Machine',
     'Theft: BOV': 'Theft: BOV',
     'Theft: Auto Parts': 'Theft: Auto Parts',
     'Theft: All Other Larceny': 'Theft: All Other Larceny'}

# %%
sample_14_15_16['Offense_Description'] = sample_14_15_16.Offense_Description.map(m)

# %%
sample_14_15_16
# Out:
#                 Offense_Description             Report_Date  \
# 0          Theft: All Other Larceny  02/24/2014 12:00:00 AM
# 1                Theft: Shoplifting  08/18/2014 12:00:00 AM
# 2                        Theft: BOV  08/22/2014 12:00:00 AM
# 3                 Theft: Auto Theft  07/19/2014 12:00:00 AM
# 4          Theft: All Other Larceny  07/14/2014 12:00:00 AM
# 5                Aggravated Assault  07/19/2014 12:00:00 AM
# 6                Theft: Shoplifting  02/18/2014 12:00:00 AM
# 7                        Theft: BOV  01/30/2014 12:00:00 AM
# 8                Theft: Shoplifting  06/25/2014 12:00:00 AM
# 9          Theft: All Other Larceny  06/13/2014 12:00:00 AM
# 10                       Theft: BOV  10/29/2014 12:00:00 AM
# 11         Theft: All Other Larceny  01/07/2014 12:00:00 AM
# 12         Theft: All Other Larceny  01/13/2014 12:00:00 AM
# 13         Theft: All Other Larceny  10/03/2014 12:00:00 AM
# 14    Burglary: Breaking & Entering  04/16/2014 12:00:00 AM
# 15               Theft: Shoplifting  11/30/2014 12:00:00 AM
# 16             Theft: from Building  12/07/2014 12:00:00 AM
# 17         Theft: All Other Larceny  01/22/2014 12:00:00 AM
# 18    Burglary: Breaking & Entering  12/27/2014 12:00:00 AM
# 19               Theft: Shoplifting  06/17/2014 12:00:00 AM
# 20         Theft: All Other Larceny  11/11/2014 12:00:00 AM
# 21    Burglary: Breaking & Entering  03/26/2014 12:00:00 AM
# 22         Theft: All Other Larceny  03/29/2014 12:00:00 AM
# 23         Theft: All Other Larceny  04/11/2014 12:00:00 AM
# 24                       Theft: BOV  03/24/2014 12:00:00 AM
# 25               Theft: Shoplifting  09/25/2014 12:00:00 AM
# 26                       Theft: BOV  02/08/2014 12:00:00 AM
# 27               Aggravated Assault  05/18/2014 12:00:00 AM
# 28                Theft: Auto Theft  11/13/2014 12:00:00 AM
# 29         Theft: All Other Larceny  11/07/2014 12:00:00 AM
# ...                             ...                     ...
# 9324                          Theft               19-Jan-16
# 9326              Theft: Auto Theft                5-Sep-16
# 9327                       Burglary               18-Mar-16
# 9328                       Burglary               19-Nov-16
# 9329                          Theft               22-Feb-16
# 9330                          Theft                6-May-16
# 9331                          Theft                5-Apr-16
# 9332                          Theft               25-Jul-16
# 9333                          Theft               20-Jul-16
# 9338                          Theft               26-Sep-16
# 9339                          Theft               18-Jun-16
# 9340                          Theft               11-May-16
# 9341                          Theft               16-Sep-16
# 9342                          Theft                4-Mar-16
# 9343                          Theft               11-Dec-16
# 9344                          Theft               19-Mar-16
# 9345                          Theft               17-Oct-16
# 9346                          Theft               18-Mar-16
# 9347                          Theft                2-Oct-16
# 9348                    Agg Assault               29-Jun-16
# 9351                          Theft                4-Jul-16
# 9353                       Burglary                1-Feb-16
# 9355                          Theft               24-Aug-16
# 9356                          Theft               16-Feb-16
# 9357                       Burglary                8-Feb-16
# 9360                          Theft                7-Feb-16
# 9361                          Theft                8-Oct-16
# 9362                          Theft                3-May-16
# 9363                          Theft               23-Feb-16
# 9364                          Theft               15-Nov-16
#
#                                            Full_Address
# 0     3101 GUADALUPE ST                             ...
# 1     1000 E 41ST ST                                ...
# 2     117 W WILLIAM CANNON DR                       ...
# 3     6407 SPRINGDALE RD                            ...
# 4     7201 BLESSING AVE                             ...
# 5     E WILLIAM CANNON DR / S IH 35 SVRD NB         ...
# 6     1030 NORWOOD PARK BLVD                        ...
# 7     1803 E ANDERSON LN SVRD EB                    ...
# 8     7301 N FM 620 RD                              ...
# 9     309 E GRADY DR                                ...
# 10    6013 S 1ST ST                                 ...
# 11    2525 W ANDERSON LN                            ...
# 12    9300 S IH 35 SVRD SB                          ...
# 13    10900 LAKELINE MALL DR                        ...
# 14    10408 O ROURK LN                              ...
# 15    1030 NORWOOD PARK BLVD                        ...
# 16    8601 RESEARCH BLVD NB                         ...
# 17    1000 E 41ST ST                                ...
# 18    9205 RESEARCH BLVD SVRD NB                    ...
# 19    11200 LAKELINE MALL DR                        ...
# 20    9323 MANCHACA RD                              ...
# 21    6408 ROSEBOROUGH DR                           ...
# 22    1221 ALGARITA AVE                             ...
# 23    401 LITTLE TEXAS LN                           ...
# 24    6301 E US 290 HWY EB                          ...
# 25    2110 W SLAUGHTER LN                           ...
# 26    6607 BRODIE LN                                ...
# 27    9070 RESEARCH BLVD SVRD SB                    ...
# 28    11001 S 1ST ST                                ...
# 29    403 E 15TH ST                                 ...
# ...                                                 ...
# 9324  3500 JEFFERSON ST                             ...
# 9326  2508 E RIVERSIDE DR                           ...
# 9327  5330 N IH 35 SVRD SB                          ...
# 9328  7415 POINSETTA LN                             ...
# 9329  3600 S IH 35 SVRD SB                          ...
# 9330  1201 BARBARA JORDAN BLVD                      ...
# 9331  2223 BURTON DR                                ...
# 9332  9333 RESEARCH BLVD NB                         ...
# 9333  6806 E RIVERSIDE DR                           ...
# 9338  1101 S MOPAC EXPY SVRD NB                     ...
# 9339  1030 NORWOOD PARK BLVD                        ...
# 9340  500 E 4TH ST                                  ...
# 9341  2300 W BEN WHITE BLVD SVRD EB                 ...
# 9342  12330 METRIC BLVD                             ...
# 9343  710 E BEN WHITE BLVD WB                       ...
# 9344  6934 E BEN WHITE BLVD EB                      ...
# 9345  1003 BARTON SPRINGS RD                        ...
# 9346  11066 PECAN PARK BLVD                         ...
# 9347  9505 STONELAKE BLVD                           ...
# 9348  1637 PAVELICH PASS                            ...
# 9351  11600 FAST HORSE DR                           ...
# 9353  6503 BLUFF SPRINGS RD                         ...
# 9355  8313 PANADERO DR                              ...
# 9356  12800 TURTLE ROCK RD                          ...
# 9357  6208 BLUE STEM TRL                            ...
# 9360  4712 S CONGRESS AVE                           ...
# 9361  2336 DOUGLAS ST                               ...
# 9362  5601 ADAIR DR                                 ...
# 9363  3603 SOUTHRIDGE DR                            ...
# 9364  2508 E RIVERSIDE DR                           ...
#
# [25045 rows x 3 columns]

# %%
sample_14_15_16.to_csv("Crime_Samples.csv")

# %% [markdown]
# ## Grouping the DF by zipcode

# %%
crime_df = pd.read_csv("Final_Crime_Zipcode.csv")

# %%
crime_df.head()
# Out:
#         Offense_Description             Report_Date  \
# 0  Theft: All Other Larceny  02/24/2014 12:00:00 AM
# 1        Theft: Shoplifting  08/18/2014 12:00:00 AM
# 2                Theft: BOV  08/22/2014 12:00:00 AM
# 3         Theft: Auto Theft  07/19/2014 12:00:00 AM
# 4  Theft: All Other Larceny  07/14/2014 12:00:00 AM
#
#                                         Full Address    Zip
# 0  3101 GUADALUPE ST                             ...  78705
# 1  1000 E 41ST ST                                ...  78751
# 2  117 W WILLIAM CANNON DR                       ...  78745
# 3  6407 SPRINGDALE RD                            ...  78723
# 4  7201 BLESSING AVE                             ...  78752

# %%
crime_counts = crime_df.groupby(['Zip', 'Offense_Description'], as_index = False).count()

# %%
# We have counts of offense type per zipcpode, now to clean that up also
crime_counts.head()
# Out:
#      Zip       Offense_Description  Report_Date  Full Address
# 0  78610  Theft: All Other Larceny            1             1
# 1  78613        Aggravated Assault            1             1
# 2  78613                  Burglary            4             4
# 3  78613                   Robbery            2             2
# 4  78613                     Theft          143           143

# %%
# check columns
crime_counts.columns
# Out:
# Index(['Zip', 'Offense_Description', 'Report_Date', 'Full Address'], dtype='object')

# %%
# remove the now unnecessary column
del crime_counts['Offense_Description']

# %%
# view the dataframe
crime_counts.head()
# Out:
#      Zip  Report_Date  Full Address
# 0  78610            1             1
# 1  78613            1             1
# 2  78613            4             4
# 3  78613            2             2
# 4  78613          143           143

# %%
# pare down the dataframe even more by grouping by zip code and report date
crime_counts = crime_counts.groupby('Zip')['Report_Date'].sum().reset_index()

# %%
# rename the zip code col so it matches the zip code boundary kml file from the census website
# this will be useful when merging this current table with the kml file on google fusion tables
crime_counts.rename_axis({"Zip": "ZCTA5CE10",
                         "Report_Date": "Crime_Counts"}, axis="columns", inplace=True)
crime_counts.head()
# Out:
#    ZCTA5CE10  Crime_Counts
# 0      78610             1
# 1      78613           242
# 2      78617           171
# 3      78652             6
# 4      78653            26

# %%
crime_counts
# Out:
#     ZCTA5CE10  Crime_Counts
# 0       78610             1
# 1       78613           242
# 2       78617           171
# 3       78652             6
# 4       78653            26
# 5       78660           101
# 6       78664             1
# 7       78701          1353
# 8       78702          1178
# 9       78703           478
# 10      78704          1722
# 11      78705           771
# 12      78712             7
# 13      78717           165
# 14      78719           108
# 15      78721           346
# 16      78722           219
# 17      78723          1366
# 18      78724           340
# 19      78725            38
# 20      78726           157
# 21      78727           325
# 22      78728             6
# 23      78729           289
# 24      78730            24
# 25      78731           328
# 26      78732             1
# 27      78733             2
# 28      78735           180
# 29      78736            56
# 30      78737             3
# 31      78739           117
# 32      78741          2130
# 33      78742            28
# 34      78744          1235
# 35      78745          1539
# 36      78746           507
# 37      78747           179
# 38      78748           967
# 39      78749           543
# 40      78750           259
# 41      78751           615
# 42      78752           838
# 43      78753          2223
# 44      78754           280
# 45      78756           210
# 46      78757           699
# 47      78758          1739
# 48      78759           927

# %%
# save as csv; this will be used in Google Fusion Tables
crime_counts.to_csv("Austin_Crimes2.csv")
