# %%
import pandas as pd

# %%
sample_2014 = pd.read_csv("2014_Crime_Data.csv")
sample_2015 = pd.read_csv("2015_Crime_Data.csv")
sample_2016 = pd.read_csv("2016_Crime_Data.csv")

# %%
sample_2014.shape
# Out:
# (10160, 6)

# %%
sample_2015.shape
# Out:
# (9643, 6)

# %%
sample_2016.shape
# Out:
# (9365, 6)

# %%
sample_14_15 = pd.concat([sample_2014, sample_2015])

# %%
sample_14_15_16 = pd.concat([sample_14_15, sample_2016])

# %%
sample_14_15_16.shape
# Out:
# (29168, 6)

# %%
sample_14_15_16.head()
# Out:
#           GO Highest Offense Desc Highest NIBRS/UCR Offense Description  \
# 0  THEFT                                       Theft: All Other Larceny
# 1  THEFT                                       Theft: All Other Larceny
# 2  THEFT OF BICYCLE                            Theft: All Other Larceny
# 3  BURGLARY OF VEHICLE                                       Theft: BOV
# 4  AUTO THEFT                                                Auto Theft
#
#            GO Report Date                                        GO Location  \
# 0  04/29/2014 12:00:00 AM  4300 SPEEDWAY                                 ...
# 1  06/17/2014 12:00:00 AM  8803 SCHICK RD                                ...
# 2  04/07/2014 12:00:00 AM  2101 RIO GRANDE ST                            ...
# 3  11/08/2014 12:00:00 AM  1901 ONION CREEK PKWY                         ...
# 4  08/14/2014 12:00:00 AM  8519 CAHILL DR                                ...
#
#            Clearance Date  GO Location Zip
# 0  05/14/2014 12:00:00 AM          78751.0
# 1  07/16/2014 12:00:00 AM          78729.0
# 2  04/17/2014 12:00:00 AM          78705.0
# 3  11/14/2014 12:00:00 AM          78748.0
# 4  10/02/2014 12:00:00 AM          78729.0

# %%
sample_14_15_16 = sample_14_15_16[['GO Highest Offense Desc', 'Highest NIBRS/UCR Offense Description',
       'GO Report Date', 'GO Location', 'GO Location Zip']]

# %%
sample_14_15_16.head(3)
# Out:
#           GO Highest Offense Desc Highest NIBRS/UCR Offense Description  \
# 0  THEFT                                       Theft: All Other Larceny
# 1  THEFT                                       Theft: All Other Larceny
# 2  THEFT OF BICYCLE                            Theft: All Other Larceny
#
#            GO Report Date                                        GO Location  \
# 0  04/29/2014 12:00:00 AM  4300 SPEEDWAY                                 ...
# 1  06/17/2014 12:00:00 AM  8803 SCHICK RD                                ...
# 2  04/07/2014 12:00:00 AM  2101 RIO GRANDE ST                            ...
#
#    GO Location Zip
# 0          78751.0
# 1          78729.0
# 2          78705.0

# %%
sample_14_15_16.duplicated().sum()
# Out:
# 3563

# %%
sample_14_15_16.shape[0] - sample_14_15_16.duplicated().sum()
# Out:
# 25605

# %%
sample_14_15_16 = sample_14_15_16.drop_duplicates()

# %%
sample_14_15_16.shape[0]
# Out:
# 25605

# %%
sample_14_15_16.isnull().sum()
# Out:
# GO Highest Offense Desc                    0
# Highest NIBRS/UCR Offense Description      0
# GO Report Date                             0
# GO Location                              451
# GO Location Zip                          115
# dtype: int64

# %%
sample_14_15_16 = sample_14_15_16.dropna()

# %%
sample_14_15_16.isnull().sum()
# Out:
# GO Highest Offense Desc                  0
# Highest NIBRS/UCR Offense Description    0
# GO Report Date                           0
# GO Location                              0
# GO Location Zip                          0
# dtype: int64

# %%
sample_14_15_16.dtypes
# Out:
# GO Highest Offense Desc                   object
# Highest NIBRS/UCR Offense Description     object
# GO Report Date                            object
# GO Location                               object
# GO Location Zip                          float64
# dtype: object

# %%
sample_14_15_16.head()
# Out:
#           GO Highest Offense Desc Highest NIBRS/UCR Offense Description  \
# 0  THEFT                                       Theft: All Other Larceny
# 1  THEFT                                       Theft: All Other Larceny
# 2  THEFT OF BICYCLE                            Theft: All Other Larceny
# 3  BURGLARY OF VEHICLE                                       Theft: BOV
# 4  AUTO THEFT                                                Auto Theft
#
#            GO Report Date                                        GO Location  \
# 0  04/29/2014 12:00:00 AM  4300 SPEEDWAY                                 ...
# 1  06/17/2014 12:00:00 AM  8803 SCHICK RD                                ...
# 2  04/07/2014 12:00:00 AM  2101 RIO GRANDE ST                            ...
# 3  11/08/2014 12:00:00 AM  1901 ONION CREEK PKWY                         ...
# 4  08/14/2014 12:00:00 AM  8519 CAHILL DR                                ...
#
#    GO Location Zip
# 0          78751.0
# 1          78729.0
# 2          78705.0
# 3          78748.0
# 4          78729.0

# %%
sample_14_15_16['Zip'] = sample_14_15_16['GO Location Zip'].astype(int)

# %%
sample_14_15_16.head()
# Out:
#           GO Highest Offense Desc Highest NIBRS/UCR Offense Description  \
# 0  THEFT                                       Theft: All Other Larceny
# 1  THEFT                                       Theft: All Other Larceny
# 2  THEFT OF BICYCLE                            Theft: All Other Larceny
# 3  BURGLARY OF VEHICLE                                       Theft: BOV
# 4  AUTO THEFT                                                Auto Theft
#
#            GO Report Date                                        GO Location  \
# 0  04/29/2014 12:00:00 AM  4300 SPEEDWAY                                 ...
# 1  06/17/2014 12:00:00 AM  8803 SCHICK RD                                ...
# 2  04/07/2014 12:00:00 AM  2101 RIO GRANDE ST                            ...
# 3  11/08/2014 12:00:00 AM  1901 ONION CREEK PKWY                         ...
# 4  08/14/2014 12:00:00 AM  8519 CAHILL DR                                ...
#
#    GO Location Zip    Zip
# 0          78751.0  78751
# 1          78729.0  78729
# 2          78705.0  78705
# 3          78748.0  78748
# 4          78729.0  78729

# %%
sample_14_15_16['Zip'] = sample_14_15_16['Zip'].astype(str)

# %%
sample_14_15_16.head()
# Out:
#           GO Highest Offense Desc Highest NIBRS/UCR Offense Description  \
# 0  THEFT                                       Theft: All Other Larceny
# 1  THEFT                                       Theft: All Other Larceny
# 2  THEFT OF BICYCLE                            Theft: All Other Larceny
# 3  BURGLARY OF VEHICLE                                       Theft: BOV
# 4  AUTO THEFT                                                Auto Theft
#
#            GO Report Date                                        GO Location  \
# 0  04/29/2014 12:00:00 AM  4300 SPEEDWAY                                 ...
# 1  06/17/2014 12:00:00 AM  8803 SCHICK RD                                ...
# 2  04/07/2014 12:00:00 AM  2101 RIO GRANDE ST                            ...
# 3  11/08/2014 12:00:00 AM  1901 ONION CREEK PKWY                         ...
# 4  08/14/2014 12:00:00 AM  8519 CAHILL DR                                ...
#
#    GO Location Zip    Zip
# 0          78751.0  78751
# 1          78729.0  78729
# 2          78705.0  78705
# 3          78748.0  78748
# 4          78729.0  78729

# %%
del sample_14_15_16['GO Location Zip']

# %%
sample_14_15_16.head()
# Out:
#           GO Highest Offense Desc Highest NIBRS/UCR Offense Description  \
# 0  THEFT                                       Theft: All Other Larceny
# 1  THEFT                                       Theft: All Other Larceny
# 2  THEFT OF BICYCLE                            Theft: All Other Larceny
# 3  BURGLARY OF VEHICLE                                       Theft: BOV
# 4  AUTO THEFT                                                Auto Theft
#
#            GO Report Date                                        GO Location  \
# 0  04/29/2014 12:00:00 AM  4300 SPEEDWAY                                 ...
# 1  06/17/2014 12:00:00 AM  8803 SCHICK RD                                ...
# 2  04/07/2014 12:00:00 AM  2101 RIO GRANDE ST                            ...
# 3  11/08/2014 12:00:00 AM  1901 ONION CREEK PKWY                         ...
# 4  08/14/2014 12:00:00 AM  8519 CAHILL DR                                ...
#
#      Zip
# 0  78751
# 1  78729
# 2  78705
# 3  78748
# 4  78729

# %%
sample_14_15_16['City'] = 'Austin'
sample_14_15_16['State'] = 'TX'

# %%
sample_14_15_16.head()
# Out:
#           GO Highest Offense Desc Highest NIBRS/UCR Offense Description  \
# 0  THEFT                                       Theft: All Other Larceny
# 1  THEFT                                       Theft: All Other Larceny
# 2  THEFT OF BICYCLE                            Theft: All Other Larceny
# 3  BURGLARY OF VEHICLE                                       Theft: BOV
# 4  AUTO THEFT                                                Auto Theft
#
#            GO Report Date                                        GO Location  \
# 0  04/29/2014 12:00:00 AM  4300 SPEEDWAY                                 ...
# 1  06/17/2014 12:00:00 AM  8803 SCHICK RD                                ...
# 2  04/07/2014 12:00:00 AM  2101 RIO GRANDE ST                            ...
# 3  11/08/2014 12:00:00 AM  1901 ONION CREEK PKWY                         ...
# 4  08/14/2014 12:00:00 AM  8519 CAHILL DR                                ...
#
#      Zip    City State
# 0  78751  Austin    TX
# 1  78729  Austin    TX
# 2  78705  Austin    TX
# 3  78748  Austin    TX
# 4  78729  Austin    TX

# %%
sample_14_15_16['Full_Address'] = sample_14_15_16['GO Location'] + sample_14_15_16['City'] + " " + sample_14_15_16['State'] + " " +  sample_14_15_16['Zip']

# %%
sample_14_15_16.head()
# Out:
#           GO Highest Offense Desc Highest NIBRS/UCR Offense Description  \
# 0  THEFT                                       Theft: All Other Larceny
# 1  THEFT                                       Theft: All Other Larceny
# 2  THEFT OF BICYCLE                            Theft: All Other Larceny
# 3  BURGLARY OF VEHICLE                                       Theft: BOV
# 4  AUTO THEFT                                                Auto Theft
#
#            GO Report Date                                        GO Location  \
# 0  04/29/2014 12:00:00 AM  4300 SPEEDWAY                                 ...
# 1  06/17/2014 12:00:00 AM  8803 SCHICK RD                                ...
# 2  04/07/2014 12:00:00 AM  2101 RIO GRANDE ST                            ...
# 3  11/08/2014 12:00:00 AM  1901 ONION CREEK PKWY                         ...
# 4  08/14/2014 12:00:00 AM  8519 CAHILL DR                                ...
#
#      Zip    City State                                       Full_Address
# 0  78751  Austin    TX  4300 SPEEDWAY                                 ...
# 1  78729  Austin    TX  8803 SCHICK RD                                ...
# 2  78705  Austin    TX  2101 RIO GRANDE ST                            ...
# 3  78748  Austin    TX  1901 ONION CREEK PKWY                         ...
# 4  78729  Austin    TX  8519 CAHILL DR                                ...

# %%
sample_14_15_16.columns
# Out:
# Index(['GO Highest Offense Desc', 'Highest NIBRS/UCR Offense Description',
#        'GO Report Date', 'GO Location', 'Zip', 'City', 'State',
#        'Full_Address'],
#       dtype='object')

# %%
sample_14_15_16 = sample_14_15_16[['Highest NIBRS/UCR Offense Description',
       'GO Report Date',
       'Full_Address']]
sample_14_15_16.head()
# Out:
#   Highest NIBRS/UCR Offense Description          GO Report Date  \
# 0              Theft: All Other Larceny  04/29/2014 12:00:00 AM
# 1              Theft: All Other Larceny  06/17/2014 12:00:00 AM
# 2              Theft: All Other Larceny  04/07/2014 12:00:00 AM
# 3                            Theft: BOV  11/08/2014 12:00:00 AM
# 4                            Auto Theft  08/14/2014 12:00:00 AM
#
#                                         Full_Address
# 0  4300 SPEEDWAY                                 ...
# 1  8803 SCHICK RD                                ...
# 2  2101 RIO GRANDE ST                            ...
# 3  1901 ONION CREEK PKWY                         ...
# 4  8519 CAHILL DR                                ...

# %%
sample_14_15_16.rename_axis({'Highest NIBRS/UCR Offense Description': 'Offense_Description',
                            'GO Report Date': 'Report_Date'}, axis=1, inplace=True)
# Out:
# /Users/arwen/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:2746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)

# %%
sample_14_15_16.head()
# Out:
#         Offense_Description             Report_Date  \
# 0  Theft: All Other Larceny  04/29/2014 12:00:00 AM
# 1  Theft: All Other Larceny  06/17/2014 12:00:00 AM
# 2  Theft: All Other Larceny  04/07/2014 12:00:00 AM
# 3                Theft: BOV  11/08/2014 12:00:00 AM
# 4                Auto Theft  08/14/2014 12:00:00 AM
#
#                                         Full_Address
# 0  4300 SPEEDWAY                                 ...
# 1  8803 SCHICK RD                                ...
# 2  2101 RIO GRANDE ST                            ...
# 3  1901 ONION CREEK PKWY                         ...
# 4  8519 CAHILL DR                                ...

# %%
m = {'Agg Assault': 'Agg Assault',
     'Theft': 'Theft',
     'Robbery': 'Robbery',
     'Burglary': 'Burglary',
     'Auto Theft': 'Theft: Auto Theft',
     'Murder' : 'Murder',
# 9348                    Agg Assault               29-Jun-16
# 9351                          Theft                4-Jul-16
# 9353                       Burglary                1-Feb-16
# 9355                          Theft               24-Aug-16
# 9356                          Theft               16-Feb-16
# 9357                       Burglary                8-Feb-16
# 9360                          Theft                7-Feb-16
# 9361                          Theft                8-Oct-16
# 9362                          Theft                3-May-16
# 9363                          Theft               23-Feb-16
# 9364                          Theft               15-Nov-16
#
#                                            Full_Address
# 0     4300 SPEEDWAY                                 ...
# 1     8803 SCHICK RD                                ...
# 2     2101 RIO GRANDE ST                            ...
# 3     1901 ONION CREEK PKWY                         ...
# 4     8519 CAHILL DR                                ...
# 5     5628 NIJMEGEN DR                              ...
# 6     15119 N IH 35 SVRD NB                         ...
# 7     2105 E 14TH ST                                ...
# 8     1222 ALGARITA AVE                             ...
# 9     500 E 7TH ST                                  ...
# 10    6007 N IH 35 SVRD NB                          ...
# 11    7439 N LAMAR BLVD                             ...
# 12    219 E 6TH ST                                  ...
# 13    6008 SANDSHOF DR                              ...
# 14    525 N LAMAR BLVD                              ...
# 15    305 W 5TH ST                                  ...
# 16    10810 N LAMAR BLVD                            ...
# 17    7201 MANCHACA RD                              ...
# 18    303 E OLTORF ST                               ...
# 19    1401 EVA ST                                   ...
# 20    8300 N FM 620 RD                              ...
# 21    1431 FAIRFIELD DR                             ...
# 22    11301 FARRAH LN                               ...
# 23    6501 SKINNER CV                               ...
# 24    8401 S 1ST ST                                 ...
# 26    1901 E ANDERSON LN SVRD EB                    ...
# 27    6201 E US 290 HWY SVRD EB                     ...
# 28    1307 SOUTHPORT DR                             ...
# 29    6301 N LAMAR BLVD                             ...
# 30    12351 N IH 35 SVRD NB                         ...
# ...                                                 ...
# 9324  3500 JEFFERSON ST                             ...
# 9326  2508 E RIVERSIDE DR                           ...
# 9327  5330 N IH 35 SVRD SB                          ...
# 9328  7415 POINSETTA LN                             ...
# 9329  3600 S IH 35 SVRD SB                          ...
# 9330  1201 BARBARA JORDAN BLVD                      ...
# 9331  2223 BURTON DR                                ...
# 9332  9333 RESEARCH BLVD NB                         ...
# 9333  6806 E RIVERSIDE DR                           ...
# 9338  1101 S MOPAC EXPY SVRD NB                     ...
# 9339  1030 NORWOOD PARK BLVD                        ...
# 9340  500 E 4TH ST                                  ...
# 9341  2300 W BEN WHITE BLVD SVRD EB                 ...
# 9342  12330 METRIC BLVD                             ...
# 9343  710 E BEN WHITE BLVD WB                       ...
# 9344  6934 E BEN WHITE BLVD EB                      ...
# 9345  1003 BARTON SPRINGS RD                        ...
# 9346  11066 PECAN PARK BLVD                         ...
# 9347  9505 STONELAKE BLVD                           ...
# 9348  1637 PAVELICH PASS                            ...
# 9351  11600 FAST HORSE DR                           ...
# 9353  6503 BLUFF SPRINGS RD                         ...
# 9355  8313 PANADERO DR                              ...
# 9356  12800 TURTLE ROCK RD                          ...
# 9357  6208 BLUE STEM TRL                            ...
# 9360  4712 S CONGRESS AVE                           ...
# 9361  2336 DOUGLAS ST                               ...
# 9362  5601 ADAIR DR                                 ...
# 9363  3603 SOUTHRIDGE DR                            ...
# 9364  2508 E RIVERSIDE DR                           ...
#
# [25066 rows x 3 columns]

# %%
sample_14_15_16.to_csv("Crime_Samples.csv")

# %%
smaller_sample = sample_14_15_16.sample(frac=0.25, replace=True)

smaller_sample.to_csv("Smaller_Sample_Data.csv", index=False)
